# %% [markdown]
# # Equity Analysis with Python - Introduction (Part 1)

# %% [markdown]
# __Please install yfinance__ with the following command (Anaconda Prompt/Terminal Window):

# %% [markdown]
# pip install yfinance

# %% [markdown]
# ## yfinance API - first steps

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
symbol = "AAPL" # ticker symbol for Apple Inc.

# %%
df = yf.download(tickers = symbol)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099722
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094519
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087582
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089749
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092351
# ...                ...         ...         ...         ...         ...
# 2023-03-31  162.440002  165.000000  161.910004  164.899994  164.899994
# 2023-04-03  164.270004  166.289993  164.220001  166.169998  166.169998
# 2023-04-04  166.600006  166.839996  165.110001  165.630005  165.630005
# 2023-04-05  164.740005  165.050003  161.800003  163.759995  163.759995
# 2023-04-06  162.429993  164.960007  162.000000  164.660004  164.660004
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# 1980-12-17   86441600
# 1980-12-18   73449600
# ...               ...
# 2023-03-31   68694700
# 2023-04-03   56976200
# 2023-04-04   46278300
# 2023-04-05   51511700
# 2023-04-06   45390100
#
# [10669 rows x 6 columns]

# %%
df.index = pd.to_datetime(df.index.date)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099722
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094519
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087582
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089749
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092351
# ...                ...         ...         ...         ...         ...
# 2023-03-31  162.440002  165.000000  161.910004  164.899994  164.899994
# 2023-04-03  164.270004  166.289993  164.220001  166.169998  166.169998
# 2023-04-04  166.600006  166.839996  165.110001  165.630005  165.630005
# 2023-04-05  164.740005  165.050003  161.800003  163.759995  163.759995
# 2023-04-06  162.429993  164.960007  162.000000  164.660004  164.660004
#
#                Volume
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# 1980-12-17   86441600
# 1980-12-18   73449600
# ...               ...
# 2023-03-31   68694700
# 2023-04-03   56976200
# 2023-04-04   46278300
# 2023-04-05   51511700
# 2023-04-06   45390100
#
# [10669 rows x 6 columns]

# %%
df.index
# Out:
# DatetimeIndex(['1980-12-12', '1980-12-15', '1980-12-16', '1980-12-17',
#                '1980-12-18', '1980-12-19', '1980-12-22', '1980-12-23',
#                '1980-12-24', '1980-12-26',
#                ...
#                '2023-03-24', '2023-03-27', '2023-03-28', '2023-03-29',
#                '2023-03-30', '2023-03-31', '2023-04-03', '2023-04-04',
#                '2023-04-05', '2023-04-06'],
#               dtype='datetime64[ns]', length=10669, freq=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10669 entries, 1980-12-12 to 2023-04-06
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       10669 non-null  float64
#  1   High       10669 non-null  float64
#  2   Low        10669 non-null  float64
#  3   Close      10669 non-null  float64
#  4   Adj Close  10669 non-null  float64
#  5   Volume     10669 non-null  int64
# dtypes: float64(5), int64(1)
# memory usage: 583.5 KB

# %% [markdown]
# - __Date__: Date (year-month-day) at midnight New York Time (business daily data without weekends and bank holidays)
# - __Open__: daily Open Price @ 9:30 am Eastern TimeZone
# - __High__: daily high/max price
# - __Low__: daily low/min price
# - __Close__: daily Close Price @ 4:00 pm Eastern TimeZone
# - __Adj Close__: Close price adjusted for Dividend Payments (backward adjusted)
# - __Volume__: daily Trading Volume (number of Shares)

# %% [markdown]
# __Price Chart__

# %%
df.Close.plot(figsize = (12, 8), fontsize = 12)
plt.ylabel("Price (USD)")
plt.title("AAPL Price Chart", fontsize = 15)
plt.show()

# %% [markdown]
# __Volume Chart__

# %%
df.loc["2022-6", "Volume"].plot(figsize = (12, 8), kind = "bar")
plt.ylabel("Volume (Shares)")
plt.title("AAPL Trading Volume (daily)", fontsize = 15)
plt.show()

# %%
df.Volume.mul(df.Close) # Trading Volume (USD Value)
# Out:
# 1980-12-12    6.019952e+07
# 1980-12-15    2.139674e+07
# 1980-12-16    1.191798e+07
# 1980-12-17    9.985128e+06
# 1980-12-18    8.730367e+06
#                   ...
# 2023-03-31    1.132776e+10
# 2023-04-03    9.467735e+09
# 2023-04-04    7.665075e+09
# 2023-04-05    8.435556e+09
# 2023-04-06    7.473934e+09
# Length: 10669, dtype: float64

# %% [markdown]
# ## Excursus: Versions and Updates

# %% [markdown]
# You can get the __latest version__ of yfinance with the following command (Anaconda Prompt/Terminal Window):

# %% [markdown]
# pip install yfinance --upgrade

# %%
yf.__version__
# Out:
# '0.2.16'

# %%
yf.download(tickers = symbol)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099722
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094519
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087582
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089749
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092351
# ...                ...         ...         ...         ...         ...
# 2023-03-31  162.440002  165.000000  161.910004  164.899994  164.899994
# 2023-04-03  164.270004  166.289993  164.220001  166.169998  166.169998
# 2023-04-04  166.600006  166.839996  165.110001  165.630005  165.630005
# 2023-04-05  164.740005  165.050003  161.800003  163.759995  163.759995
# 2023-04-06  162.429993  164.960007  162.000000  164.660004  164.660004
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# 1980-12-17   86441600
# 1980-12-18   73449600
# ...               ...
# 2023-03-31   68694700
# 2023-04-03   56976200
# 2023-04-04   46278300
# 2023-04-05   51511700
# 2023-04-06   45390100
#
# [10669 rows x 6 columns]

# %% [markdown]
# ## Analysis Period

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099722
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094519
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087582
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089749
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092351
# ...                ...         ...         ...         ...         ...
# 2023-03-31  162.440002  165.000000  161.910004  164.899994  164.899994
# 2023-04-03  164.270004  166.289993  164.220001  166.169998  166.169998
# 2023-04-04  166.600006  166.839996  165.110001  165.630005  165.630005
# 2023-04-05  164.740005  165.050003  161.800003  163.759995  163.759995
# 2023-04-06  162.429993  164.960007  162.000000  164.660004  164.660004
#
#                Volume
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# 1980-12-17   86441600
# 1980-12-18   73449600
# ...               ...
# 2023-03-31   68694700
# 2023-04-03   56976200
# 2023-04-04   46278300
# 2023-04-05   51511700
# 2023-04-06   45390100
#
# [10669 rows x 6 columns]

# %%
df.loc["2022-01-01":"2022-01-15"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 
980-12-17    0.115513    0.116071    0.115513    0.115513    0.089749
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092351
# ...                ...         ...         ...         ...         ...
# 2023-03-31  162.440002  165.000000  161.910004  164.899994  164.899994
# 2023-04-03  164.270004  166.289993  164.220001  166.169998  166.169998
# 2023-04-04  166.600006  166.839996  165.110001  165.630005  165.630005
# 2023-04-05  164.740005  165.050003  161.800003  163.759995  163.759995
# 2023-04-06  162.429993  164.960007  162.000000  164.660004  164.660004
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# 1980-12-17   86441600
# 1980-12-18   73449600
# ...               ...
# 2023-03-31   68694700
# 2023-04-03   56976200
# 2023-04-04   46278300
# 2023-04-05   51511700
# 2023-04-06   45390100
#
# [10669 rows x 6 columns]

# %% [markdown]
# ## Data Frequency

# %% [markdown]
# Valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo <br>
# (Intraday data cannot extend last 60 days)

# %% [markdown]
# __daily (default)__

# %%
df = yf.download(tickers = symbol, interval = "1d")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099722
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094519
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087582
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089749
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092351
# ...                ...         ...         ...         ...         ...
# 2023-03-31  162.440002  165.000000  161.910004  164.899994  164.899994
# 2023-04-03  164.270004  166.289993  164.220001  166.169998  166.169998
# 2023-04-04  166.600006  166.839996  165.110001  165.630005  165.630005
# 2023-04-05  164.740005  165.050003  161.800003  163.759995  163.759995
# 2023-04-06  162.429993  164.960007  162.000000  164.660004  164.660004
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# 1980-12-17   86441600
# 1980-12-18   73449600
# ...               ...
# 2023-03-31   68694700
# 2023-04-03   56976200
# 2023-04-04   46278300
# 2023-04-05   51511700
# 2023-04-06   45390100
#
# [10669 rows x 6 columns]

# %% [markdown]
# __monthly__

# %%
df = yf.download(tickers = symbol, interval = "1mo")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1985-01-01    0.130022    0.138951    0.124442    0.129464    0.100589
# 1985-02-01    0.129464    0.137277    0.110491    0.110491    0.085847
# 1985-03-01    0.110491    0.116071    0.092634    0.098772    0.076742
# 1985-04-01    0.098772    0.102679    0.087612    0.094866    0.073707
# 1985-05-01    0.094866    0.099330    0.075335    0.077567    0.060267
# ...                ...         ...         ...         ...         ...
# 2022-12-01  148.210007  150.919998  125.870003  129.929993  129.731918
# 2023-01-01  130.279999  147.229996  124.169998  144.289993  144.070023
# 2023-02-01  143.970001  157.380005  141.320007  147.410004  147.185272
# 2023-03-01  146.830002  165.000000  143.899994  164.899994  164.899994
# 2023-04-01  164.270004  166.839996  161.800003  164.660004  164.660004
#
#                 Volume
# Date
# 1985-01-01  6366416000
# 1985-02-01  4733388800
# 1985-03-01  4615587200
# 1985-04-01  2868028800
# 1985-05-01  4639129600
# ...                ...
# 2022-12-01  1675731200
# 2023-01-01  1443652500
# 2023-02-01  1307198900
# 2023-03-01  1520017600
# 2023-04-01   200156300
#
# [460 rows x 6 columns]

# %% [markdown]
# __weekly__

# %%
df = yf.download(tickers = symbol, interval = "1wk")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-08    0.128348    0.128906    0.128348    0.128348    0.099722
# 1980-12-15    0.122210    0.126674    0.112723    0.126116    0.097987
# 1980-12-22    0.132254    0.159040    0.132254    0.158482    0.123135
# 1980-12-29    0.160714    0.161272    0.152344    0.154018    0.119666
# 1981-01-05    0.151228    0.151228    0.135045    0.142299    0.110561
# ...                ...         ...         ...         ...         ...
# 2023-03-06  153.789993  156.300003  147.610001  148.500000  148.500000
# 2023-03-13  147.809998  156.740005  147.699997  155.000000  155.000000
# 2023-03-20  155.070007  162.139999  154.149994  160.250000  160.250000
# 2023-03-27  159.940002  165.000000  155.979996  164.899994  164.899994
# 2023-04-03  164.270004  166.839996  161.800003  164.660004  164.660004
#
#                Volume
# Date
# 1980-12-08  469033600
# 1980-12-15  490134400
# 1980-12-22  187891200
# 1980-12-29  219452800
# 1981-01-05  197904000
# ...               ...
# 2023-03-06  313350800
# 2023-03-13  410426600
# 2023-03-20  350100100
# 2023-03-27  267884600
# 2023-04-03  200156300
#
# [2209 rows x 6 columns]

# %% [markdown]
# __intraday - 1h__

# %%
df = yf.download(tickers = symbol, interval = "1h")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: 1h data not available for startTime=345479400 and endTime=1681148979. The requested range must be within the last 730 days.
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
df = yf.download(tickers = symbol, period = "1y", interval = "1h")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2022-04-11 09:30:00-04:00  168.710007  169.029999  166.365005  166.479996
# 2022-04-11 10:30:00-04:00  166.490005  167.039993  166.100006  166.440002
# 2022-04-11 11:30:00-04:00  166.440002  167.205002  166.399994  166.559998
# 2022-04-11 12:30:00-04:00  166.550003  167.460007  166.550003  166.910004
# 2022-04-11 13:30:00-04:00  166.910004  167.250000  166.490005  166.664993
# ...                               ...         ...         ...         ...
# 2023-04-10 09:30:00-04:00  161.419998  162.000000  160.080002  160.154999
# 2023-04-10 10:30:00-04:00  160.160004  161.399994  160.145004  161.134995
# 2023-04-10 11:30:00-04:00  161.140793  161.610001  160.600006  160.820801
# 2023-04-10 12:30:00-04:00  160.830002  161.613098  160.820007  161.569901
# 2023-04-10 13:30:00-04:00  161.570007  161.630005  161.309998  161.559998
#
#                             Adj Close    Volume
# Datetime
# 2022-04-11 09:30:00-04:00  166.479996  19251032
# 2022-04-11 10:30:00-04:00  166.440002   8804591
# 2022-04-11 11:30:00-04:00  166.559998   6208228
# 2022-04-11 12:30:00-04:00  166.910004   6214791
# 2022-04-11 13:30:00-04:00  166.664993   5672112
# ...                               ...       ...
# 2023-04-10 09:30:00-04:00  160.154999  15225797
# 2023-04-10 10:30:00-04:00  161.134995   6669628
# 2023-04-10 11:30:00-04:00  160.820801   4330948
# 2023-04-10 12:30:00-04:00  161.569901   4302297
# 2023-04-10 13:30:00-04:00  161.559998   1014599
#
# [1744 rows x 6 columns]

# %% [markdown]
# __intraday - 1m__

# %%
df = yf.download(tickers = symbol, period = "1y", interval = "1m")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: 1m data not available for startTime=1649612988 and endTime=1681148988. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
df = yf.download(tickers = symbol, period = "1wk", interval = "1m")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-04-03 13:50:00-04:00  164.699997  164.699997  164.630005  164.660004
# 2023-04-03 13:51:00-04:00  164.660004  164.690002  164.639999  164.654999
# 2023-04-03 13:52:00-04:00  164.649994  164.677795  164.630005  164.656906
# 2023-04-03 13:53:00-04:00  164.649994  164.660004  164.580002  164.589996
# 2023-04-03 13:54:00-04:00  164.600006  164.660004  164.574997  164.645004
# ...                               ...         ...         ...         ...
# 2023-04-10 13:45:00-04:00  161.440002  161.449997  161.382797  161.429993
# 2023-04-10 13:46:00-04:00  161.440002  161.499298  161.414993  161.494995
# 2023-04-10 13:47:00-04:00  161.500000  161.570007  161.500000  161.550003
# 2023-04-10 13:48:00-04:00  161.554993  161.598999  161.539993  161.539993
# 2023-04-10 13:49:00-04:00  161.509995  161.509995  161.509995  161.509995
#
#                             Adj Close  Volume
# Datetime
# 2023-04-03 13:50:00-04:00  164.660004       0
# 2023-04-03 13:51:00-04:00  164.654999   53765
# 2023-04-03 13:52:00-04:00  164.656906   51838
# 2023-04-03 13:53:00-04:00  164.589996   57073
# 2023-04-03 13:54:00-04:00  164.645004   71613
# ...                               ...     ...
# 2023-04-10 13:45:00-04:00  161.429993   50158
# 2023-04-10 13:46:00-04:00  161.494995   69052
# 2023-04-10 13:47:00-04:00  161.550003   76715
# 2023-04-10 13:48:00-04:00  161.539993   47662
# 2023-04-10 13:49:00-04:00  161.509995       0
#
# [1559 rows x 6 columns]

# %% [markdown]
# ## Dividends

# %% [markdown]
# __Dividend__: A dividend is a __distribution of profits__ by a corporation to its shareholders.

# %% [markdown]
# Companies are __free__ to distribute (all / parts / none) of their profits to shareholders (Dividend Payout Policy)

# %% [markdown]
# Dividend Payouts are an import __source of income__ for equity investors.

# %% [markdown]
# __Total Return/Profit__ of stocks consists of:
# - Stock Price Increase
# - Dividend Payouts

# %% [markdown]
# - For __innovative & high-growth__ companies, __Stock Price Increase__ is relatively more important.
# - For __mature & highly profitable__ companies, __Dividend Payouts__ can be a significant part of Total Return/Profit.

# %% [markdown]
# -> __Don´t omit Dividend Payouts__ in your Analysis / Performance Comparison! (otherwise, high-dividend stocks get penalized!)

# %% [markdown]
# __For this and the next lectures, you have the choice between__
# - option 1: working with the same data as in the videos (saved in the csv file aapl.csv) __RECOMMENDED!!!__
# - option 2: working with your specific maximum time period

# %%
# option 1 -> same data as in video
df = pd.read_csv("aapl.csv", index_col = "Date", parse_dates = ["Date"]) # for more information, see lecture "Saving and Loading Data (Local Files)"  
df

# %%
# option 2 -> max period
# df = yf.download(tickers = symbol, actions = True) 
# df

# %%
df.loc[df.Dividends != 0]

# %%
df.Dividends.sum() # cumulative Dividends per share

# %%
df.Close[-1] - df.Close[0] # cumulative Stock Price Increase

# %%
df.loc[df.Dividends != 0].Dividends.plot()
plt.show()

# %% [markdown]
# -> AAPL Dividend Policy:
# - historically __low-dividend__ stock (focus on growth)
# - Dividend Payouts __smoothed and steadily growing__ (highly predictable)
# - __Avoiding Dividend Cuts__ in less profitable years (negative signal in the market)

# %% [markdown]
# ## What´s the Adjusted Close Price?

# %% [markdown]
# "The Adjusted Close Price is the backward adjusted (reduced) Close Price (adjusted for Dividends)."

# %%
df

# %%
df2 = df[["Close", "Adj Close", "Dividends"]].copy()
df2

# %%
df2.loc["2015":].plot(figsize = (12, 8), secondary_y = "Dividends")
plt.show()

# %%
df2[df2.Dividends > 0]

# %%
last_div = df2.loc["2022-08-01": "2022-08-5"].copy()
last_div

# %%
last_div.Close - last_div["Adj Close"]

# %% [markdown]
# https://in.help.yahoo.com/kb/adjusted-close-sln28256.html

# %%
multiplier = (1 - 0.23/165.809998)
multiplier

# %%
last_div

# %%
last_div["Adj Close calc"] = last_div.Close * multiplier
last_div

# %%
df["Adj Close"] / df["Close"] # total multiplier (all dividends)

# %%
df

# %% [markdown]
# __Interpretations:__
# - Borrowing parts (e.g. 22%) of initial stock purchase price in 1980 and pay back borrowed amounts with Dividends. -or-
# - Reinvesting Dividends and buying more shares with Dividends

# %% [markdown]
# __Benefits:__
# - good approximation for a Stock´s __Total Return__ (Price Return + Dividend Yield)
# - allows __Performance Comparison__ across stocks with different Payout Policies

# %% [markdown]
# ## Stock Splits

# %%
df

# %% [markdown]
# All Prices (OHLC, Adj Close) and Dividends are __backward adjusted__ (reduced) for Stock Splits.

# %% [markdown]
# -> This __makes perfectly sense__ and you should not question it (unless you are interested in historical observable prices)!

# %%
splits = df.loc[df["Stock Splits"] > 0]
splits

# %% [markdown]
# __Stock Split__: allows a company to break (split) each share into multiple shares __without affecting its market capitalization (total value of all its shares) or each investor's stake__ in the company. Motivation: reduce price per share and increase granularity.

# %% [markdown]
# __Example Stock Split 4:1__ -> Receive 4 new shares for 1 old share. Share Price immediately drops to 1/4 (no value effect)

# %% [markdown]
# On Yahoo Finance, Prices & Dividends are backward adjusted for Stock Splits.

# %% [markdown]
# Price on 2020-08-31 __after Split__:

# %%
splits.loc["2020-08-31", "Close"]

# %% [markdown]
# Price on 2020-08-31 __before Split__:

# %%
splits.loc["2020-08-31", "Close"] * splits.loc["2020-08-31", "Stock Splits"]

# %% [markdown]
# __-> 4 * 129 == 1 * 516__

# %% [markdown]
# __Calculate the unadjusted (observable) prices__

# %%
df["Stock Splits"].replace(to_replace = 0, value = 1, inplace = True) # 1:1 on all other days
df

# %%
df["Multiplier"] = df.sort_index(ascending = False)["Stock Splits"].cumprod() # cumulative multipier
df

# %%
df["Close_unadj"] = df["Close"] * df.Multiplier # observable close price
df

# %%
df[["Close", "Close_unadj"]].plot(figsize = (12 ,8))
plt.vlines(splits.index, 0, 700, color = "black")
plt.show()

# %% [markdown]
# __-> (backward adjusted) prices correctly reflect true price performance. They ignore price drops caused by stock splits!__

# %% [markdown]
# __unadjusted Dividends__

# %%
df["div_unadj"] = df["Dividends"] * df.Multiplier

# %%
df.loc[df.div_unadj != 0].div_unadj.plot(figsize = (12, 8))
plt.show()

# %% [markdown]
# __unadjusted Trading Volume (number of shares)__

# %%
df["Volume_unadj"] = df["Volume"] / df.Multiplier

# %%
df["Volume_unadj"].plot(figsize = (12, 8))
plt.show()

# %% [markdown]
# ## Stocks from other Countries / Exchanges

# %%
yf.download(tickers = "AAPL") # US Ticker (no suffix)

# %%
yf.download(tickers = "RELIANCE") # Indian Ticker (no suffix)

# %% [markdown]
# __Exchange List:__

# %% [markdown]
# https://help.yahoo.com/kb/SLN2310.html

# %%
yf.download(tickers = "RELIANCE.NS") # Indian Ticker

# %%
yf.download(tickers = "LHA.DE") # German Ticker (Deutsche Boerse XETRA)

# %%
yf.download(tickers = "LHA.F") # German Ticker (Frankfurt Stock Exchange)

# %% [markdown]
# ## Multiple Tickers

# %%
df = yf.download(tickers = ["AAPL", "MSFT"]) # multiple tickers
df

# %%
df.info()

# %%
df.columns

# %%
df.Close # outer index level

# %%
df.loc[:, ("Close", "MSFT")] # one specific column

# %%
df.Close.MSFT # one specific column

# %%
df.loc[:, (slice(None), slice("AAPL"))] # inner index level

# %%
df = df.swaplevel(axis = "columns").sort_index(axis = "columns")
df

# %%
df.AAPL

# %%
df = yf.download(tickers = ["LHA.F", "LHA.DE"]).Close
df

# %%
df.LHA.F # incorrect

# %%
df["LHA.F"]

# %%
df.columns = ["LHA_DE", "LHA_F"]

# %%
df

# %%
df.LHA_F

# %% [markdown]
# ## Saving and Loading Data (Local Files)

# %%
import yfinance as yf
import pandas as pd

# %%
symbol = "AAPL"

# %%
df = yf.download(symbol)
df

# %%
df.to_csv(path_or_buf = "apple.csv") # writing to local csv

# %%
df2 = pd.read_csv("apple.csv", index_col="Date", parse_dates= ["Date"]) # loading from local csv
df2

# %%
df2.info()

# %% [markdown]
# __multiple symbols__

# %%
symbols = ["AAPL", "MSFT"]

# %%
df = yf.download(symbols)
df

# %%
df.to_csv(path_or_buf = "two_stocks.csv") # writing to local csv

# %%
df2 = pd.read_csv("two_stocks.csv", header = [0, 1], index_col = [0], parse_dates = [0]) # loading from local csv
df2

# %%
df2.info()

# %% [markdown]
# ## Coding Challenge

# %% [markdown]
# 1. Load historical Prices, Volume and Dividends for the stocks "JNJ" (__Johnson & Johnson__) and "TSLA" (__Tesla__)

# %% [markdown]
# 2. Analyze and compare Dividends, Stock Price Increase and Dividend Policy

# %% [markdown]
# 3. Which stock is the high-dividend stock?

# %% [markdown]
# ## --------------- Solution --------------------------

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
symbols = ["JNJ", "TSLA"]

# %%
df = yf.download(symbols, actions = True)
df

# %%
df.Close.plot(figsize = (12, 8))
plt.show()

# %%
df = df.swaplevel(axis = "columns").sort_index(axis = "columns")
df

# %%
jnj = df.JNJ
jnj

# %%
jnj[["Close", "Adj Close"]].plot(figsize = (12, 8))
plt.show()

# %% [markdown]
# __Dividends__

# %%
jnj.Dividends.sum()

# %% [markdown]
# __Price Increase__

# %%
jnj.Close[-1] - jnj.Close[0]

# %% [markdown]
# __Dividend Policy__

# %%
jnj.loc[jnj.Dividends != 0].Dividends.plot()
plt.show()

# %%
tsla = df.TSLA.dropna()
tsla

# %%
tsla[["Close", "Adj Close"]].plot(figsize = (12, 8))
plt.show()

# %% [markdown]
# __Dividends__

# %%
tsla.Dividends.sum()

# %% [markdown]
# __Price Increase__

# %%
tsla.Close[-1] - tsla.Close[0]

# %% [markdown]
# __Dividend Policy__

# %%
tsla.loc[tsla.Dividends != 0].Dividends.plot()
plt.show()

# %% [markdown]
# __-> JNJ is the high-dividend stock__
